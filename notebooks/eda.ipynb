# %%
# %pwd
# Out:
# 'c:\\Users\\Ayush\\OneDrive\\Desktop\\smart-traffic\\notebooks'

# %%
import os

os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Ayush\\OneDrive\\Desktop\\smart-traffic'

# %%
from src.ingestion.data_ingestion import DataIngestion

ingestor = DataIngestion()

df = ingestor.load_csv(
    folder="..//interim",
    file_name="clean_accidents_city_level.csv"
)
df.head()
# Out:
# [INFO] Loaded CSV: clean_accidents_city_level.csv, Shape: (51, 17)
#    sl_no                   city  2022_accidents  2023_accidents  \
# 0    1.0                   Agra             NaN             NaN
# 1    2.0              Ahmedabad             NaN             NaN
# 2    3.0  Allahabad (Prayagraj)             NaN             NaN
# 3    4.0               Amritsar           117.0           147.0
# 4    5.0       Asansol Durgapur           494.0           500.0
#
#    2022_ranking_accidents  2023_ranking_accidents  2022_killed  2023_killed  \
# 0                    28.0                    29.0        548.0        499.0
# 1                    19.0                    19.0        488.0        535.0
# 2                    24.0                    24.0        603.0        582.0
# 3                    50.0                    50.0         82.0        110.0
# 4                    40.0                    42.0        359.0        353.0
#
#    2022_ranking_killed  2023_ranking_killed  2022_injured  2023_injured  \
# 0                  9.0                 11.0         795.0         657.0
# 1                 11.0                  8.0         795.0         657.0
# 2                  6.0                  5.0         886.0         865.0
# 3                 48.0                 48.0          62.0          73.0
# 4                 17.0                 17.0         309.0         271.0
#
#    2022_ranking_injured  2023_ranking_injured  accident_growth  \
# 0                  29.0                  31.0              NaN
# 1                  21.0                  21.0              NaN
# 2                  28.0                  28.0              NaN
# 3                  50.0                  50.0             30.0
# 4                  44.0                  44.0              6.0
#
#    severity_ratio  injury_ratio
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3        0.748299      0.496599
# 4        0.706000      0.542000

# %%
df.describe()
# Out:
#            sl_no  2022_accidents  2023_accidents  2022_ranking_accidents  \
# count  51.000000       48.000000       48.000000               51.000000
# mean   25.980392      592.770833      607.645833               25.431373
# std    14.833058      229.609589      238.851996               14.439190
# min     1.000000      117.000000      147.000000                1.000000
# 25%    13.500000      475.250000      490.750000               13.500000
# 50%    26.000000      568.000000      619.000000               25.000000
# 75%    38.500000      744.000000      686.000000               37.500000
# max    50.000000      926.000000      991.000000               50.000000
#
#        2023_ranking_accidents  2022_killed  2023_killed  2022_ranking_killed  \
# count               51.000000    51.000000    51.000000            51.000000
# mean                25.490196   323.392157   325.941176            25.333333
# std                 14.431040   181.134986   181.141648            14.443915
# min                  1.000000    53.000000    56.000000             1.000000
# 25%                 13.500000   188.500000   199.500000            13.500000
# 50%                 25.000000   310.000000   308.000000            25.000000
# 75%                 37.500000   394.500000   389.500000            37.500000
# max                 50.000000   772.000000   915.000000            50.000000
#
#        2023_ranking_killed  2022_injured  2023_injured  2022_ranking_injured  \
# count            51.000000     51.000000     51.000000             51.000000
# mean             25.431373    534.235294    602.431373             25.411765
# std              14.439190    239.872932    270.055421             14.437696
# min               1.000000     62.000000     73.000000              1.000000
# 25%              13.500000    370.000000    417.500000             13.500000
# 50%              25.000000    505.000000    583.000000             25.000000
# 75%              37.500000    638.000000    848.000000             37.500000
# max              50.000000    939.000000    993.000000             50.000000
#
#        2023_ranking_injured  accident_growth  severity_ratio  injury_ratio
# count             51.000000        48.000000       48.000000     48.000000
# mean              25.431373        14.875000        0.631892      1.205236
# std               14.439190       135.110928        0.568497      1.208278
# min                1.000000      -549.000000        0.117647      0.310345
# 25%               13.500000         2.000000        0.327993      0.696284
# 50%               25.000000        19.000000        0.414803      0.759115
# 75%               37.500000        91.000000        0.704086      1.060676
# max               50.000000       256.000000        2.763736      5.456044

# %%
df.sort_values(by="2023_accidents", ascending=False).head(10)
# Out:
#     sl_no        city  2022_accidents  2023_accidents  2022_ranking_accidents  \
# 15   16.0     Gwalior           886.0           991.0                    13.0
# 16   17.0   Hyderabad           886.0           991.0                     9.0
# 17   18.0      Indore           886.0           991.0                     2.0
# 18   19.0    Jabalpur           886.0           991.0                     3.0
# 14   15.0   Ghaziabad           886.0           991.0                    30.0
# 19   20.0      Jaipur           886.0           991.0                     8.0
# 33   34.0      Meerut           926.0           939.0                    29.0
# 34   35.0      Mumbai           926.0           939.0                    17.0
# 35   36.0      Nagpur           926.0           939.0                    27.0
# 32   33.0  Mallapuram           744.0           768.0                     7.0
#
#     2023_ranking_accidents  2022_killed  2023_killed  2022_ranking_killed  \
# 15                    16.0        353.0        344.0                 19.0
# 16                     7.0        323.0        335.0                 23.0
# 17                     5.0        639.0        257.0                  5.0
# 18                     3.0        481.0        545.0                 12.0
# 14                    30.0        363.0        365.0                 16.0
# 19                     8.0        765.0        849.0                  3.0
# 33                    31.0        345.0        395.0                 21.0
# 34                    12.0        371.0        384.0                 14.0
# 35                    27.0        310.0        308.0                 25.0
# 32                     6.0        320.0        309.0                 24.0
#
#     2023_ranking_killed  2022_injured  2023_injured  2022_ranking_injured  \
# 15                 19.0         638.0         703.0                  18.0
# 16                 20.0         638.0         703.0                  10.0
# 17                 31.0         638.0         703.0                   3.0
# 18                  7.0         638.0         703.0                   2.0
# 14                 16.0         638.0         703.0                  30.0
# 19                  3.0         638.0         703.0                  12.0
# 33                 13.0         935.0         848.0                  26.0
# 34                 14.0         935.0         848.0                  17.0
# 35                 25.0         935.0         848.0                  23.0
# 32                 23.0         601.0         583.0                   5.0
#
#     2023_ranking_injured  accident_growth  severity_ratio  injury_ratio
# 15                  18.0            105.0        0.347124      0.709384
# 16                  10.0            105.0        0.338042      0.709384
# 17                   7.0            105.0        0.259334      0.709384
# 18                   2.0            105.0        0.549950      0.709384
# 14                  30.0            105.0        0.368315      0.709384
# 19                  11.0            105.0        0.856710      0.709384
# 33                  29.0             13.0        0.420660      0.903088
# 34                   9.0             13.0        0.408946      0.903088
# 35                  23.0             13.0        0.328009      0.903088
# 32                   5.0             24.0        0.402344      0.759115

# %%
df.sort_values(by="accident_growth", ascending=False).head(10)
# Out:
#     sl_no        city  2022_accidents  2023_accidents  2022_ranking_accidents  \
# 12   13.0     Dhanbad           179.0           435.0                    48.0
# 20   21.0  Jamshedpur           167.0           329.0                    49.0
# 28   29.0        Kota           444.0           592.0                    44.0
# 29   30.0     Lucknow           444.0           592.0                    25.0
# 14   15.0   Ghaziabad           886.0           991.0                    30.0
# 15   16.0     Gwalior           886.0           991.0                    13.0
# 18   19.0    Jabalpur           886.0           991.0                     3.0
# 16   17.0   Hyderabad           886.0           991.0                     9.0
# 19   20.0      Jaipur           886.0           991.0                     8.0
# 17   18.0      Indore           886.0           991.0                     2.0
#
#     2023_ranking_accidents  2022_killed  2023_killed  2022_ranking_killed  \
# 12                    46.0        114.0        306.0                 45.0
# 20                    47.0         68.0        218.0                 49.0
# 28                    38.0        111.0        114.0                 46.0
# 29                    22.0        587.0        568.0                  7.0
# 14                    30.0        363.0        365.0                 16.0
# 15                    16.0        353.0        344.0                 19.0
# 18                     3.0        481.0        545.0                 12.0
# 16                     7.0        323.0        335.0                 23.0
# 19                     8.0        765.0        849.0                  3.0
# 17                     5.0        639.0        257.0                  5.0
#
#     2023_ranking_killed  2022_injured  2023_injured  2022_ranking_injured  \
# 12                 26.0          73.0         135.0                  49.0
# 20                 33.0         115.0         214.0                  48.0
# 28                 47.0         432.0         641.0                  39.0
# 29                  6.0         935.0         983.0                  26.0
# 14                 16.0         638.0         703.0                  30.0
# 15                 19.0         638.0         703.0                  18.0
# 18                  7.0         638.0         703.0                   2.0
# 16                 20.0         638.0         703.0                  10.0
# 19                  3.0         638.0         703.0                  12.0
# 17                 31.0         638.0         703.0                   3.0
#
#     2023_ranking_injured  accident_growth  severity_ratio  injury_ratio
# 12                  49.0            256.0        0.703448      0.310345
# 20                  45.0            162.0        0.662614      0.650456
# 28                  33.0            148.0        0.192568      1.082770
# 29                  26.0            148.0        0.959459      1.660473
# 14                  30.0            105.0        0.368315      0.709384
# 15                  18.0            105.0        0.347124      0.709384
# 18                   2.0            105.0        0.549950      0.709384
# 16                  10.0            105.0        0.338042      0.709384
# 19                  11.0            105.0        0.856710      0.709384
# 17                   7.0            105.0        0.259334      0.709384

# %%
import matplotlib.pyplot as plt

top_cities = df.sort_values(by="2023_accidents", ascending=False).head(10)

plt.figure()
plt.bar(top_cities['city'], top_cities['2023_accidents'])
plt.xticks(rotation=45)
plt.title("Top 10 Cities by Accidents (2023)")
plt.show()

# %%
plt.figure()
plt.scatter(df['2023_accidents'], df['severity_ratio'])
plt.xlabel("Accidents")
plt.ylabel("Severity Ratio")
plt.title("Accidents vs Severity")
plt.show()

# %%
import folium

map_india = folium.Map(location=[22.5, 78.9], zoom_start=5)
map_india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31bea9d113d29b791736e26201eeb13e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31bea9d113d29b791736e26201eeb13e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31bea9d113d29b791736e26201eeb13e = L.map(
#                 &quot;map_31bea9d113d29b791736e26201eeb13e&quot;,
#                 {
#                     center: [22.5, 78.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85d97c35b9265361a96990d6e466f68c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85d97c35b9265361a96990d6e466f68c.addTo(map_31bea9d113d29b791736e26201eeb13e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in top_cities.iterrows():
    folium.Marker(
        location=[22.5, 78.9],  # placeholder
        popup=f"{row['city']}: {row['2023_accidents']}"
    ).add_to(map_india)

map_india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31bea9d113d29b791736e26201eeb13e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31bea9d113d29b791736e26201eeb13e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31bea9d113d29b791736e26201eeb13e = L.map(
#                 &quot;map_31bea9d113d29b791736e26201eeb13e&quot;,
#                 {
#                     center: [22.5, 78.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85d97c35b9265361a96990d6e466f68c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85d97c35b9265361a96990d6e466f68c.addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#             tile_layer_85d97c35b9265361a96990d6e466f68c.addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#             var marker_95c68ea296b3f5ed454ddaf048505d9b = L.marker(
#                 [22.5, 78.9],
#                 {
# }
#             ).addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#         var popup_3fded91bd2a127b354a38e616016b0ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9afd318c24e713235f481dbb4c3c64fd = $(`&lt;div id=&quot;html_9afd318c24e713235f481dbb4c3c64fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gwalior: 991.0&lt;/div&gt;`)[0];
#                 popup_3fded91bd2a127b354a38e616016b0ad.setContent(html_9afd318c24e713235f481dbb4c3c64fd);
#
#
#
#         marker_95c68ea296b3f5ed454ddaf048505d9b.bindPopup(popup_3fded91bd2a127b354a38e616016b0ad)
#         ;
#
#
#
#
#             var marker_7b042b5184e588382270ff01b9bb44f0 = L.marker(
#                 [22.5, 78.9],
#                 {
# }
#             ).addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#         var popup_23fb4100319d33cb1f3fd7451e853719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9089b2f0e8d376b168c908afbf335a5f = $(`&lt;div id=&quot;html_9089b2f0e8d376b168c908afbf335a5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hyderabad: 991.0&lt;/div&gt;`)[0];
#                 popup_23fb4100319d33cb1f3fd7451e853719.setContent(html_9089b2f0e8d376b168c908afbf335a5f);
#
#
#
#         marker_7b042b5184e588382270ff01b9bb44f0.bindPopup(popup_23fb4100319d33cb1f3fd7451e853719)
#         ;
#
#
#
#
#             var marker_880a0a7e56032f95c51d047aad04b8b7 = L.marker(
#                 [22.5, 78.9],
#                 {
# }
#             ).addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#         var popup_70f2fd4f18b6190883afdccd98009ee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffba4248318c1bca736e8667573943f5 = $(`&lt;div id=&quot;html_ffba4248318c1bca736e8667573943f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Indore: 991.0&lt;/div&gt;`)[0];
#                 popup_70f2fd4f18b6190883afdccd98009ee4.setContent(html_ffba4248318c1bca736e8667573943f5);
#
#
#
#         marker_880a0a7e56032f95c51d047aad04b8b7.bindPopup(popup_70f2fd4f18b6190883afdccd98009ee4)
#         ;
#
#
#
#
#             var marker_66e0be29510bd368091d7cd63e6a0492 = L.marker(
#                 [22.5, 78.9],
#                 {
# }
#             ).addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#         var popup_b7bef8cc25e5263ce17e165c51b5de73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_425d5341270d5d4060babcdd278a470a = $(`&lt;div id=&quot;html_425d5341270d5d4060babcdd278a470a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jabalpur: 991.0&lt;/div&gt;`)[0];
#                 popup_b7bef8cc25e5263ce17e165c51b5de73.setContent(html_425d5341270d5d4060babcdd278a470a);
#
#
#
#         marker_66e0be29510bd368091d7cd63e6a0492.bindPopup(popup_b7bef8cc25e5263ce17e165c51b5de73)
#         ;
#
#
#
#
#             var marker_c138410a4b9d84d52369dad320961d3e = L.marker(
#                 [22.5, 78.9],
#                 {
# }
#             ).addTo(map_31bea9d113d29b791736e26201eeb13e);
#
#
#         var popup_77e9a99173b070204e7ed1c0c84f467c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67846b46ed63654312532a68f797f188 = $(`&lt;div id=&quot;html_67846b46ed63654312532a68f797f188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ghaziabad: 991.0&lt;/div&gt;`)[0];
#                 popup_77e9a99173b070204e7ed1c0c84f467c.setContent(html_67846b46ed6

# %%
df_traffic = ingestor.load_excel(
    "traffic",
    "Final_Majestic_to_AIM_jan-2016tomarch-2018.xlsx"
)
# Out:
# [INFO] Loaded Excel: Final_Majestic_to_AIM_jan-2016tomarch-2018.xlsx, Shape: (821, 23)

# %%
print(df_traffic.columns)
# Out:
# Index(['Date', 'Origin Movement ID', 'Origin Display Name',
#        'Destination Movement ID', 'Destination Display Name',
#        'Daily Mean Travel Time (Seconds)',
#        'Daily Range - Lower Bound Travel Time (Seconds)',
#        'Daily Range - Upper Bound Travel Time (Seconds)',
#        'AM Mean Travel Time (Seconds)',
#        'AM Range - Lower Bound Travel Time (Seconds)',
#        'AM Range - Upper Bound Travel Time (Seconds)',
#        'PM Mean Travel Time (Seconds)',
#        'PM Range - Lower Bound Travel Time (Seconds)',
#        'PM Range - Upper Bound Travel Time (Seconds)',
#        'Midday Mean Travel Time (Seconds)',
#        'Midday Range - Lower Bound Travel Time (Seconds)',
#        'Midday Range - Upper Bound Travel Time (Seconds)',
#        'Evening Mean Travel Time (Seconds)',
#        'Evening Range - Lower Bound Travel Time (Seconds)',
#        'Evening Range - Upper Bound Travel Time (Seconds)',
#        'Early Morning Mean Travel Time (Seconds)',
#        'Early Morning Range - Lower Bound Travel Time (Seconds)',
#        'Early Morning Range - Upper Bound Travel Time (Seconds)'],
#       dtype='str')

# %%
df_traffic.columns = df_traffic.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df_traffic['date'] = pd.to_datetime(df_traffic['date'], errors='coerce')

# %%
df_traffic['year'] = df_traffic['date'].dt.year
df_traffic['month'] = df_traffic['date'].dt.month
df_traffic['day'] = df_traffic['date'].dt.day
df_traffic['day_of_week'] = df_traffic['date'].dt.dayofweek

# %%
df_traffic['avg_travel_time'] = df_traffic[
    'daily_mean_travel_time_(seconds)'
]

df_traffic['am_peak'] = df_traffic[
    'am_mean_travel_time_(seconds)'
]

df_traffic['pm_peak'] = df_traffic[
    'pm_mean_travel_time_(seconds)'
]

# %%
df_traffic['congestion_index'] = (
    df_traffic['pm_mean_travel_time_(seconds)'] /
    df_traffic['early_morning_mean_travel_time_(seconds)']
)

# %%
import matplotlib.pyplot as plt

daily_avg = df_traffic.groupby('date')['avg_travel_time'].mean()

plt.figure()
daily_avg.plot()
plt.title("Daily Average Travel Time")
plt.show()

# %%
import pandas as pd
coords = pd.read_csv("data/raw/external/city_coordinates.csv")

df_geo = df.merge(coords, on="city", how="left")

df_geo.head()
# Out:
#    sl_no                   city  2022_accidents  2023_accidents  \
# 0    1.0                   Agra             NaN             NaN
# 1    2.0              Ahmedabad             NaN             NaN
# 2    3.0  Allahabad (Prayagraj)             NaN             NaN
# 3    4.0               Amritsar           117.0           147.0
# 4    5.0       Asansol Durgapur           494.0           500.0
#
#    2022_ranking_accidents  2023_ranking_accidents  2022_killed  2023_killed  \
# 0                    28.0                    29.0        548.0        499.0
# 1                    19.0                    19.0        488.0        535.0
# 2                    24.0                    24.0        603.0        582.0
# 3                    50.0                    50.0         82.0        110.0
# 4                    40.0                    42.0        359.0        353.0
#
#    2022_ranking_killed  2023_ranking_killed  2022_injured  2023_injured  \
# 0                  9.0                 11.0         795.0         657.0
# 1                 11.0                  8.0         795.0         657.0
# 2                  6.0                  5.0         886.0         865.0
# 3                 48.0                 48.0          62.0          73.0
# 4                 17.0                 17.0         309.0         271.0
#
#    2022_ranking_injured  2023_ranking_injured  accident_growth  \
# 0                  29.0                  31.0              NaN
# 1                  21.0                  21.0              NaN
# 2                  28.0                  28.0              NaN
# 3                  50.0                  50.0             30.0
# 4                  44.0                  44.0              6.0
#
#    severity_ratio  injury_ratio      lat      lon
# 0             NaN           NaN  27.1767  78.0081
# 1             NaN           NaN  23.0225  72.5714
# 2             NaN           NaN  25.4358  81.8463
# 3        0.748299      0.496599  31.6340  74.8723
# 4        0.706000      0.542000  23.5500  87.2900

# %%
# Delete the last row
df_geo = df_geo[:-1]

# %%
df_geo.isnull().sum()
# Out:
# sl_no                     0
# city                      0
# 2022_accidents            3
# 2023_accidents            3
# 2022_ranking_accidents    0
# 2023_ranking_accidents    0
# 2022_killed               0
# 2023_killed               0
# 2022_ranking_killed       0
# 2023_ranking_killed       0
# 2022_injured              0
# 2023_injured              0
# 2022_ranking_injured      0
# 2023_ranking_injured      0
# accident_growth           3
# severity_ratio            3
# injury_ratio              3
# lat                       0
# lon                       0
# dtype: int64

# %%
df_geo = df_geo.dropna()

# %%
import geopandas as gpd
from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(df_geo['lon'], df_geo['lat'])]

gdf = gpd.GeoDataFrame(df_geo, geometry=geometry)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

coords = gdf[['lat', 'lon']].values

db = DBSCAN(eps=1.5, min_samples=2).fit(coords)

gdf['cluster'] = db.labels_

# %%
import folium
from folium.plugins import HeatMap

map_india = folium.Map(location=[22.5, 78.9], zoom_start=5)

heat_data = [[row['lat'], row['lon'], row['2023_accidents']] 
             for _, row in gdf.iterrows()]

HeatMap(heat_data).add_to(map_india)

map_india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78211578e3735174b6ce68ea098203b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78211578e3735174b6ce68ea098203b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78211578e3735174b6ce68ea098203b0 = L.map(
#                 &quot;map_78211578e3735174b6ce68ea098203b0&quot;,
#                 {
#                     center: [22.5, 78.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c88b16a0b807e761077cb607af6e797 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c88b16a0b807e761077cb607af6e797.addTo(map_78211578e3735174b6ce68ea098203b0);
#
#
#             var heat_map_20d732e84c133423a02b939bbeb3e446 = L.heatLayer(
#                 [[31.634, 74.8723, 147.0], [23.55, 87.29, 500.0], [19.8762, 75.3433, 619.0], [12.9716, 77.5946, 619.0], [23.2599, 77.4126, 619.0], [30.7333, 76.7794, 182.0], [11.0168, 76.9558, 182.0], [13.0827, 80.2707, 182.0], [28.6139, 77.209, 182.0], [23.7957, 86.4304, 435.0], [28.4089, 77.3178, 598.0], [28.6692, 77.4538, 991.0], [26.2183, 78.1828, 991.0], [17.385, 78.4867, 991.0], [22.7196, 75.8577, 991.0], [23.1815, 79.9864, 991.0], [26.9124, 75.7873, 991.0], [22.8046, 86.2029, 329.0], [26.2389, 73.0243, 686.0], [11.8745, 75.3704, 686.0], [26.4499, 80.3319, 686.0], [11.2588, 75.7804, 686.0], [9.9312, 76.2673, 686.0], [22.5726, 88.3639, 686.0], [8.8932, 76.6141, 686.0], [25.2138, 75.8648, 592.0], [26.8467, 80.9462, 592.0], [30.901, 75.8573, 504.0], [9.9252, 78.1198, 768.0], [11.051, 76.0711, 768.0], [28.9845, 77.7064, 939.0], [19.076, 72.8777, 939.0], [21.1458, 79.0882, 939.0], [19.9975, 73.7898, 481.0], [25.5941, 85.1376, 322.0], [18.5204, 73.8567, 322.0], [21.2514, 81.6296, 322.0], [22.3039, 70.8022, 494.0], [34.0837, 74.7973, 476.0], [21.1702, 72.8311, 650.0], [8.5241, 76.9366, 650.0], [10.5276, 76.2144, 650.0], [10.7905, 78.7047, 619.0], [22.3072, 73.1812, 566.0], [25.3176, 82.9739, 558.0], [16.5062, 80.648, 558.0], [17.6868, 83.2185, 558.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_20d732e84c133423a02b939bbeb3e446.addTo(map_78211578e3735174b6ce68ea098203b0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
